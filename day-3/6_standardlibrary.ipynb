# %%
import array
arr = array.array('i',[1,2,3,4])
arr
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','cherry']))
# Out:
# 9
# apple

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Jatin Dhiman\OneDrive\Desktop\Computer-Vision\day-3

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data={'name':'Jatin','age':20}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Jatin", "age": 20}
# <class 'str'>
# {'name': 'Jatin', 'age': 20}
# <class 'dict'>
