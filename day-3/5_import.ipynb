# %%
# In Python, modules and packages help organize and reuse code.how to
# import them ?.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np

# %%
from math import *

# %%
from package.math import addition
addition(2,3)
# Out:
# 5

# %%
from package.subpackages.mult import multiply
multiply(2,3)
# Out:
# 6
